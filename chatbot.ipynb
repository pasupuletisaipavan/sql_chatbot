# %%
pip install langchain  langgraph  langchain-community
# Out:
# Requirement already satisfied: langchain in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (1.2.10)
# Requirement already satisfied: langgraph in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (1.0.9)
# Requirement already satisfied: langchain-community in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langchain) (1.2.14)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langgraph) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langgraph) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langgraph) (0.3.8)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.6)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (4.12.1)
# Requirement already satisfied: certifi in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.9)
# Requirement already satisfied: idna in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langchain-community) (2.0.46)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langchain-community) (2.13.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langchain-community) (2.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.6.3)
# Requirement already satisfied: greenlet>=1 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install langchain-ollama
# Out:
# Requirement already satisfied: langchain-ollama in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (1.0.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langchain-ollama) (1.2.14)
# Requirement already satisfied: ollama<1.0.0,>=0.6.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langchain-ollama) (0.6.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.7.6)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.25.0)
# Requirement already satisfied: anyio in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (4.12.1)
# Requirement already satisfied: certifi in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (1.0.9)
# Requirement already satisfied: idna in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.6.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pymysql
# Out:
# Requirement already satisfied: pymysql in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (1.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from langchain_ollama import ChatOllama

model = ChatOllama(
    base_url="http:/localhost:11434",
    model="llama3",
    temperature=0.5,
    max_tokens=250
)

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Sai Pavan\Documents\Projects\LANGCHAINTRAINING\sql_chatbot\backend\venv\Scripts\python.exe

# %%
pip install cryptography
# Out:
# Requirement already satisfied: cryptography in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (46.0.5)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from cryptography) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\sai pavan\documents\projects\langchaintraining\sql_chatbot\backend\venv\lib\site-packages (from cffi>=2.0.0->cryptography) (3.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.utilities import SQLDatabase
from sqlalchemy.engine import URL
import os

url = URL.create(
    drivername="mysql+pymysql",
    username="root",
    password=os.getenv("DB_PASSWORD"),
    host="localhost",
    port=int(os.getenv("DB_PORT", 3306)),
    database="college",
    query={"charset": "utf8mb4"},
)

db = SQLDatabase.from_uri(url)
print(f"Dialect: {db.dialect}")
print(f"Available tables: {db.get_usable_table_names()}")

for table in db.get_usable_table_names():
    print(db.run(f"SELECT * FROM {table} LIMIT 5;"))
# Out:
# Dialect: mysql
# Available tables: ['dept', 'student', 'teacher']
# [(101, 'english'), (103, 'IT')]
# [(101, 'anil', 78, 'C', 'Pune'), (102, 'bhumika', 93, 'A', 'Mumbai'), (103, 'chetan', 85, 'B', 'Mumbai'), (104, 'dhruv', 96, 'A', 'Delhi'), (105, 'emanuel', 92, 'F', 'Delhi')]
# [(101, 'Adam', 101), (102, 'Eve', 103)]

# %%
from langchain_community.agent_toolkits import SQLDatabaseToolkit

toolkit = SQLDatabaseToolkit(db=db, llm=model)

tools = toolkit.get_tools()

for tool in tools:
    print(f"{tool.name}: {tool.description}\n")
# Out:
# sql_db_query: Input to this tool is a detailed and correct SQL query, output is a result from the database. If the query is not correct, an error message will be returned. If an error is returned, rewrite the query, check the query, and try again. If you encounter an issue with Unknown column 'xxxx' in 'field list', use sql_db_schema to query the correct table fields.
#
# sql_db_schema: Input to this tool is a comma-separated list of tables, output is the schema and sample rows for those tables. Be sure that the tables actually exist by calling sql_db_list_tables first! Example Input: table1, table2, table3
#
# sql_db_list_tables: Input is an empty string, output is a comma-separated list of tables in the database.
#
# sql_db_query_checker: Use this tool to double check if your query is correct before executing it. Always use this tool before executing a query with sql_db_query!

# %%
import requests, pathlib

url = "https://storage.googleapis.com/benchmarks-artifacts/chinook/Chinook.db"
local_path = pathlib.Path("C:\\Users\\Sai Pavan\\Downloads\\chinook.db")

if local_path.exists():
    print(f"{local_path} already exists, skipping download.")
else:
    response = requests.get(url)
    if response.status_code == 200:
        local_path.write_bytes(response.content)
        print(f"File downloaded and saved as {local_path}")
    else:
        print(f"Failed to download the file. Status code: {response.status_code}")
# Out:
# C:\Users\Sai Pavan\Downloads\chinook.db already exists, skipping download.

# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///Chinook.db")

print(f"Dialect: {db.dialect}")
print(f"Available tables: {db.get_usable_table_names()}")
print(f'Sample output: {db.run("SELECT * FROM depts LIMIT 5;")}')
# Out:
# Dialect: sqlite
# Available tables: ['Album', 'Artist', 'Customer', 'Employee', 'Genre', 'Invoice', 'InvoiceLine', 'MediaType', 'Playlist', 'PlaylistTrack', 'Track']
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\Sai Pavan\Documents\Projects\LANGCHAINTRAINING\sql_chatbot\backend\venv\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File c:\Users\Sai Pavan\Documents\Projects\LANGCHAINTRAINING\sql_chatbot\backend\venv\Lib\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# OperationalError: no such table: depts
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[21], line 7
#       5 print(f"Dialect: {db.dialect}")
#       6 print(f"Available tables: {db.get_usable_table_names()}")
# ----> 7 print(f'Sample output: {db.run("SELECT * FROM depts LIMIT 5;")}')
#
# File c:\Users\Sai Pavan\Documents\Projects\LANGCHAINTRAINING\sql_chatbot\backend\venv\Lib\site-packages\langchain_community\utilities\sql_database.py:578, in SQLDatabase.run(self, command, fetch, include_columns, parameters, execution_options)
#     564 def run(
#     565     self,
#     566     command: Union[str, Executable],
#    (...)    571     execution_options: Optional[Dict[str, Any]] = None,
#     572 ) -> Union[str, Sequence[Dict[str, Any]], Result[Any]]:
#     573     """Execute a SQL command and return a string representing the results.
#     574
#     575     If the statement returns rows, a string of the results is returned.
#     576     If the statement returns no rows, an empty string is returned.
#     577     """
# --> 578     result = self._execute(
#     579         command, fetch, parameters=parameters, execution_options=execution_options
#     580     )
#     582     if fetch == "cursor":
#     583         return result
#
# File c:\Users\Sai Pavan\Documents\Projects\LANGCHAINTRAINING\sql_chatbot\backend\venv\Lib\site-packages\langchain_community\utilities\sql_database.py:543, in SQLDatabase._execute(self, command, fetch, parameters, execution_options)
#     541 else:
#     542     raise TypeError(f"Query expression has unknown type: {type(command)}")
# --> 543 cursor = connection.execute(
#     544     command,
#     545     parameters,
#     546     execution_options=execution_options,
#     547 )
#     549 if cursor.returns_rows:
#     550     if fetch == "all":
#
# File c:\Users\Sai Pavan\Documents\Projects\LANGCHAINTRAINING\sql_chatbot\backend\venv\Lib\site-packages\sqlalchemy\engine\base.py:1419, in Connection.execute(self, statement, parameters, execution_options)
#    1417     raise exc.ObjectNotExecutableError(statement) from err
#    1418 else:
# -> 1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# File c:\Users\Sai Pavan\Documents\Projects\LANGCHAINTRAINING\sql_chatbot\backend\venv\Lib\site-packages\sqlalchemy\sql\elements.py:527, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     525     if TYPE_CHECKING:
#     526         assert isinstance(self, Executable)
# --> 527     return connection._execute_clauseelement(
#     528         self, distilled_params, execution_options
#     529     )
#     530 else:
#     531     raise exc.ObjectNotExecutableError(self)
#
# File c:\Users\Sai Pavan\Documents\Projects\LANGCHAINTRAINING\sql_chatbot\backend\venv\Lib\site-packages\sqlalchemy\engine\base.py:1641, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1629 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1630     "compiled_cache", self.engine._compiled_cache
#    1631 )
#    1633 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1634     dialect=dialect,
#    1635     compiled_cache=compiled_cache,
#    (...)   1639     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1640 )
# -> 1641 ret = self._execute_context(
#    1642     dialect,
#    1643     dialect.execution_ctx_cls._init_compiled,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     execution_options,
#    1647     compiled_sql,
#    1648     distilled_parameters,
#    1649     elem,
#    1650     extracted_params,
#    1651     cache_hit=cache_hit,
#    1652 )
#    1653 if has_events:
#    1654     self.dispatch.after_execute(
#    1655         self,
#    1656         elem,
#    (...)   1660         ret,
#    1661     )
#
# File c:\Users\Sai Pavan\Documents\Projects\LANGCHAINTRAINING\sql_chatbot\backend\venv\Lib\site-packages\sqlalchemy\engine\base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File c:\Users\Sai Pavan\Documents\Projects\LANGCHAINTRAINING\sql_chatbot\backend\venv\Lib\site-packages\sqlalchemy\engine\base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File c:\Users\Sai Pavan\Documents\Projects\LANGCHAINTRAINING\sql_chatbot\backend\venv\Lib\site-packages\sqlalchemy\engine\base.py:2363, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2361 elif should_wrap:
#    2362     assert sqlalchemy_exception is not None
# -> 2363     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2364 else:
#    2365     assert exc_info[1] is not None
#
# File c:\Users\Sai Pavan\Documents\Projects\LANGCHAINTRAINING\sql_chatbot\backend\venv\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)   1978         context.executemany,
#    1979     )
#
# File c:\Users\Sai Pavan\Documents\Projects\LANGCHAINTRAINING\sql_chatbot\backend\venv\Lib\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# OperationalError: (sqlite3.OperationalError) no such table: depts
# [SQL: SELECT * FROM depts LIMIT 5;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
